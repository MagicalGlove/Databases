# %%
from pymongo import MongoClient
import pandas as pd
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_20312\2496211532.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv(r"../../DBData/2017_-_Cities_Community_Wide_Emissions.csv")
df.head()

cluster = MongoClient("mongodb+srv://user:password420@ola2cluster.bijj3hs.mongodb.net/")
db = cluster["ola2db"]
collection = db["cities_community_wide_emissions"]

# %%
def insert_doc(document):
    try:
        collection.insert_one(document)
        print("Document inserted successfully.")
    except Exception as e:
        print(f"Error inserting document: {e}")

# %%
for index, row in df.iterrows():
    doc = { "city_id": row["Account number"],
            "reporting_year": row["Reporting year"],
            "accounting_year":row["Accounting year"],
            "boundary": row["Boundary"],
            "protocol": row["Protocol"],
            "gases": row["Gases included"].split(";") if pd.notna(row["Gases included"]) else [],
            "total_emissions": row["Total emissions (metric tonnes CO2e)"],
            "total_scope_1": row["Total Scope 1 Emissions (metric tonnes CO2e)"],
            "total_scope_2": row["Total Scope 2 Emissions (metric tonnes CO2e)"],
            "increase_decrease": row["Increase/Decrease from last year"],
            "reason_for_increase":row["Reason for increase/decrease in emissions"]
            }
    insert_doc(doc)
# Out:
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# Document inserted successfully.
# ...

# %%
df.head(
)
# Out:
#    Account number                     Organization                 City  \
# 0           49363  Nelson Mandela Bay Municipality  Nelson Mandela Bay
# 1           31171           Ayuntamiento de Madrid               Madrid
# 2            3417                    New York City        New York City
# 3           59537               City of Denton, TX           Denton, TX
# 4           35894                Ville de Montreal             Montreal
#
#         Country         Region  C40  Access  Reporting year  \
# 0  South Africa         Africa  NaN  Public            2017
# 1         Spain         Europe  C40  Public            2017
# 2           USA  North America  C40  Public            2017
# 3           USA  North America  NaN  Public            2017
# 4        Canada  North America  C40  Public            2017
#
#            Accounting year                                       Boundary  \
# 0  2013-07-01 - 2014-06-30                            A metropolitan area
# ...
