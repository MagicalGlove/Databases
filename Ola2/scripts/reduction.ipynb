# %%
from pymongo import MongoClient
import pandas as pd;
import numpy as np;

# %%
cluster = MongoClient("mongodb+srv://user:password420@ola2cluster.bijj3hs.mongodb.net/")

db = cluster["ola2db"]
emissions_reduction_collection = db["emissions_reduction"]

# %%
emissions_reduction_2016 = pd.read_csv('../2016_-_Cities_Emissions_Reduction_Targets_20240207.csv')
emissions_reduction_2017 = pd.read_csv("../2017_-_Cities_Emissions_Reduction_Targets_20240207.csv")

reduction16 = emissions_reduction_2016[["Account No", 
                                        "Reporting Year", 
                                        "Target boundary", 
                                        "Baseline year", 
                                        "Baseline emissions (metric tonnes CO2e)", 
                                        "Percentage reduction target",
                                        "Target date",
                                        "Comment"]]

reduction17 =  emissions_reduction_2017[["Account No",
                                         "Reporting year",
                                         "Type of target",
                                         "Sector",
                                         "Baseline year",
                                         "Baseline emissions (metric tonnes CO2e)",
                                         "Percentage reduction target",
                                         "Target date",
                                         "Estimated business as usual absolute emissions in target year (metric tonnes CO2e)",
                                         "​Intensity unit (emissions per)",
                                         "Comment"]]

reduction16 = reduction16.rename(columns= {"Account No":"city_id",
                                           "Reporting Year":"reporting_year",
                                           "Target boundary":"target_boundary",
                                           "Baseline year":"baseline_year",
                                           "Baseline emissions (metric tonnes CO2e)":"baseline_emissions",
                                           "Percentage reduction target":"percentage_reduction_target",
                                           "Target date":"target_date",
                                           "Comment":"comment"})

reduction17 = reduction17.rename(columns= {"Account No":"city_id",
                                           "Reporting year":"reporting_year",
                                           "Target boundary":"target_boundary",
                                           "Baseline year":"baseline_year",
                                           "Baseline emissions (metric tonnes CO2e)":"baseline_emissions",
                                           "Percentage reduction target":"percentage_reduction_target",
                                           "Target date":"target_date",
                                           "Comment":"comment",
                                           "Type of target":"type_of_target",
                                           "Estimated business as usual absolute emissions in target year (metric tonnes CO2e)":"estimated_target",
                                           "Sector":"sector",
                                           "Access":"access",
                                           "​Intensity unit (emissions per)":"intensity_unit"})

reductionFinal = pd.concat([reduction16, reduction17])
data = reductionFinal.to_dict(orient='records')
for item in data:
    for key, value in list(item.items()):
        if pd.isna(value):
            del item[key]
emissions_reduction_collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('65fbff409a3c5bdcd56cd01d'), ObjectId('65fbff409a3c5bdcd56cd01e'), ObjectId('65fbff409a3c5bdcd56cd01f'), ObjectId('65fbff409a3c5bdcd56cd020'), ObjectId('65fbff409a3c5bdcd56cd021'), ObjectId('65fbff409a3c5bdcd56cd022'), ObjectId('65fbff409a3c5bdcd56cd023'), ObjectId('65fbff409a3c5bdcd56cd024'), ObjectId('65fbff409a3c5bdcd56cd025'), ObjectId('65fbff409a3c5bdcd56cd026'), ObjectId('65fbff409a3c5bdcd56cd027'), ObjectId('65fbff409a3c5bdcd56cd028'), ObjectId('65fbff409a3c5bdcd56cd029'), ObjectId('65fbff409a3c5bdcd56cd02a'), ObjectId('65fbff409a3c5bdcd56cd02b'), ObjectId('65fbff409a3c5bdcd56cd02c'), ObjectId('65fbff409a3c5bdcd56cd02d'), ObjectId('65fbff409a3c5bdcd56cd02e'), ObjectId('65fbff409a3c5bdcd56cd02f'), ObjectId('65fbff409a3c5bdcd56cd030'), ObjectId('65fbff409a3c5bdcd56cd031'), ObjectId('65fbff409a3c5bdcd56cd032'), ObjectId('65fbff409a3c5bdcd56cd033'), ObjectId('65fbff409a3c5bdcd56cd034'), ObjectId('65fbff409a3c5bdcd56cd035'), ObjectId('65fbff409a3c5bdcd56cd036'), ObjectId('65fbff409a3c5bdcd56cd037'), ObjectId('65fbff409a3c5bdcd56cd038'), ObjectId('65fbff409a3c5bdcd56cd039'), ObjectId('65fbff409a3c5bdcd56cd03a'), ObjectId('65fbff409a3c5bdcd56cd03b'